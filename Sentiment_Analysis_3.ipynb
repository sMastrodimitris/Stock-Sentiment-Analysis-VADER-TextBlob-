# %%
#Api Key
#a3374395f2fc41158855563e298403c6

# %% [markdown]
# +Άλλο εκτός Vader

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #########################################################################################

# %%
pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (2025.1.31)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
import requests
import json
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import os
from datetime import datetime

# %%
# Download NLTK resources (only need to run once)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# NewsAPI parameters
api_key = "a3374395f2fc41158855563e298403c6"  # Replace with your actual NewsAPI key
companies = [
    "Apple", "Microsoft", "Nvidia", "TSMC", "Tesla",
    "Walmart", "Visa", "JPMorgan", "Tencent", "United Health",
    "Costco", "Netflix", "Johnson & Johnson", "Novo Nordisk",
    "Alibaba", "Hermes", "Nestle", "Cisco", "Palantir"
]
start_date = "2025-03-22"
end_date = "2025-03-23"

# Create a directory for results if it doesn't exist
results_dir = "company_sentiment_results"
os.makedirs(results_dir, exist_ok=True)

# Initialize the sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Summary DataFrame to store aggregate results for all companies
summary_results = pd.DataFrame(columns=[
    'company', 'articles_count', 'avg_sentiment_raw',
    'avg_sentiment_processed', 'combined_sentiment', 'predicted_movement',
    'positive_count', 'neutral_count', 'negative_count'
])

# %%
# Preprocessing function
def preprocess_text(text):
    if pd.isna(text):
        return ""

    # Convert to lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)

    # Remove special characters and numbers
    text = re.sub(r'\@\w+|\#|\d+', '', text)

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Tokenize
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    # Join tokens back into text
    processed_text = ' '.join(tokens)

    return processed_text

# Function to get sentiment scores
def analyze_sentiment(text):
    if pd.isna(text) or text == "":
        return 0  # neutral score for empty text

    # Get sentiment scores
    sentiment_dict = analyzer.polarity_scores(text)

    # Return compound score (normalized between -1 and 1)
    return sentiment_dict['compound']

# Categorize sentiment
def categorize_sentiment(score):
    if score >= 0.1:
        return 'Positive'
    elif score <= -0.1:
        return 'Negative'
    else:
        return 'Neutral'

# Function to predict market movement
def predict_movement(score):
    if score > 0.15:
        return "UP"
    elif score < -0.15:
        return "DOWN"
    else:
        return "NEUTRAL"

# %%
# Process each company
for company in companies:
    print(f"\n{'='*50}")
    print(f"Processing {company}...")

    # NewsAPI endpoint
    url = f"https://newsapi.org/v2/everything?q={company}&from={start_date}&to={end_date}&language=en&sortBy=publishedAt&apiKey={api_key}"

    # Make the request
    response = requests.get(url)
    data = response.json()

    # Process the results
    if data['status'] == 'ok' and len(data.get('articles', [])) > 0:
        # Create a list to store article data
        articles_data = []

        for article in data['articles']:
            article_info = {
                'title': article.get('title', ''),
                'description': article.get('description', ''),
                'content': article.get('content', ''),
                'url': article.get('url', ''),
                'publishedAt': article.get('publishedAt', '')
            }
            articles_data.append(article_info)

        # Convert to DataFrame
        df = pd.DataFrame(articles_data)

        # Apply preprocessing to text columns
        df['processed_title'] = df['title'].apply(preprocess_text)
        df['processed_description'] = df['description'].apply(preprocess_text)
        df['processed_content'] = df['content'].apply(preprocess_text)

        # Apply sentiment analysis on both raw and processed text
        # Raw text sentiment analysis
        df['title_sentiment_raw'] = df['title'].apply(analyze_sentiment)
        df['description_sentiment_raw'] = df['description'].apply(analyze_sentiment)
        df['content_sentiment_raw'] = df['content'].apply(analyze_sentiment)

        # Processed text sentiment analysis
        df['title_sentiment_processed'] = df['processed_title'].apply(analyze_sentiment)
        df['description_sentiment_processed'] = df['processed_description'].apply(analyze_sentiment)
        df['content_sentiment_processed'] = df['processed_content'].apply(analyze_sentiment)

        # Calculate weighted average sentiment
        df['overall_sentiment_raw'] = (
            df['title_sentiment_raw'] * 0.5 +
            df['description_sentiment_raw'] * 0.4 +
            df['content_sentiment_raw'] * 0.1
        )

        df['overall_sentiment_processed'] = (
            df['title_sentiment_processed'] * 0.5 +
            df['description_sentiment_processed'] * 0.4 +
            df['content_sentiment_processed'] * 0.1
        )

        # Categorize sentiment
        df['sentiment_category_raw'] = df['overall_sentiment_raw'].apply(categorize_sentiment)
        df['sentiment_category_processed'] = df['overall_sentiment_processed'].apply(categorize_sentiment)

        # Save detailed results for this company
        company_filename = f"{company.replace(' ', '_').lower()}_sentiment_{start_date}_to_{end_date}.csv"
        company_filepath = os.path.join(results_dir, company_filename)
        df.to_csv(company_filepath, index=False)

        # Calculate summary metrics
        raw_avg = df['overall_sentiment_raw'].mean()
        processed_avg = df['overall_sentiment_processed'].mean()
        combined_avg = (raw_avg + processed_avg) / 2
        sentiment_prediction = predict_movement(combined_avg)

        # Count sentiment categories
        sentiment_counts = df['sentiment_category_processed'].value_counts()
        positive_count = sentiment_counts.get('Positive', 0)
        neutral_count = sentiment_counts.get('Neutral', 0)
        negative_count = sentiment_counts.get('Negative', 0)

        # Add to summary results
        summary_results = pd.concat([summary_results, pd.DataFrame([{
            'company': company,
            'articles_count': len(df),
            'avg_sentiment_raw': raw_avg,
            'avg_sentiment_processed': processed_avg,
            'combined_sentiment': combined_avg,
            'predicted_movement': sentiment_prediction,
            'positive_count': positive_count,
            'neutral_count': neutral_count,
            'negative_count': negative_count
        }])], ignore_index=True)

        # Display summary for this company
        print(f"\nSentiment Analysis Summary for {company}:")
        print(f"Articles analyzed: {len(df)}")
        print(f"Average Raw Sentiment: {raw_avg:.4f}")
        print(f"Average Processed Sentiment: {processed_avg:.4f}")
        print(f"Combined Average Sentiment: {combined_avg:.4f}")
        print(f"Predicted Market Movement: {sentiment_prediction}")

        # Display sentiment distribution
        print("\nSentiment Distribution:")
        print(df['sentiment_category_processed'].value_counts())

        # Display most positive/negative headlines
        print("\nMost Positive Headlines:")
        print(df.nlargest(3, 'title_sentiment_raw')[['title', 'title_sentiment_raw']])

        print("\nMost Negative Headlines:")
        print(df.nsmallest(3, 'title_sentiment_raw')[['title', 'title_sentiment_raw']])

    else:
        print(f"Error retrieving data for {company}: {data.get('message', 'Unknown error')}")
        # Add empty row to summary with error indication
        summary_results = pd.concat([summary_results, pd.DataFrame([{
            'company': company,
            'articles_count': 0,
            'avg_sentiment_raw': None,
            'avg_sentiment_processed': None,
            'combined_sentiment': None,
            'predicted_movement': 'ERROR',
            'positive_count': 0,
            'neutral_count': 0,
            'negative_count': 0
        }])], ignore_index=True)

# Save summary results
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
summary_filepath = os.path.join(results_dir, f"all_companies_summary_{timestamp}.csv")
summary_results.to_csv(summary_filepath, index=False)
# Out:
# ==================================================
# Processing Apple...
# <ipython-input-7-59b6be752eb2>:82: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_results = pd.concat([summary_results, pd.DataFrame([{
# Sentiment Analysis Summary for Apple:
# Articles analyzed: 97
# Average Raw Sentiment: 0.1768
# Average Processed Sentiment: 0.1936
# Combined Average Sentiment: 0.1852
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    56
# Neutral     30
# Negative    11
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 56  My days of forgetting to drink water are over ...               0.7269
# 92  Wendy Williams: I’m Totally Fine and Should Be...               0.6893
# 58  ‘Flying Fercos’ chronicles unique family, bygo...               0.6808
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 77  Gel’s Streaming Accounts Got Hacked With Some ...              -0.8519
# 57  Jaywalking in NYC is set to be legal — but the...              -0.6705
# 32  How Did We Not Know Severance Star Adam Scott ...              -0.6486
#
# ==================================================
# Processing Microsoft...
#
# Sentiment Analysis Summary for Microsoft:
# Articles analyzed: 98
# Average Raw Sentiment: 0.1945
# Average Processed Sentiment: 0.2146
# Combined Average Sentiment: 0.2046
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    64
# Neutral     20
# Negative    14
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 12           11 awesome AI tools you can use for free               0.8126
# 84  Legacy Trust Acquires 630 Shares of Microsoft ...               0.6705
# 7   Alphabet (GOOGL) Strengthens AI and Cloud Secu...               0.6597
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 66   Five Critical Indicators To Gauge Recession Risk              -0.7351
# 70  Jensen Huang's quantum mea culpa didn't convin...              -0.6416
# 94  iMessage scams on the rise: Tax refunds and to...              -0.5859
#
# ==================================================
# Processing Nvidia...
#
# Sentiment Analysis Summary for Nvidia:
# Articles analyzed: 99
# Average Raw Sentiment: 0.1793
# Average Processed Sentiment: 0.1985
# Combined Average Sentiment: 0.1889
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    56
# Neutral     28
# Negative    15
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 70  One Of LG’s Best 65-Inch 4K OLED Smart TVs Fro...               0.9184
# 32  ROSEN, LEADING INVESTOR COUNSEL, Encourages Mo...               0.8074
# 76  The historical figures who inspired Nvidia's p...               0.7184
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 58   Five Critical Indicators To Gauge Recession Risk              -0.7351
# 42  RTX 40 GPU owners suffering from BSODs and cra...              -0.6808
# 56  Jensen Huang's quantum mea culpa didn't convin...              -0.6416
#
# ==================================================
# Processing TSMC...
#
# Sentiment Analysis Summary for TSMC:
# Articles analyzed: 16
# Average Raw Sentiment: 0.1695
# Average Processed Sentiment: 0.1723
# Combined Average Sentiment: 0.1709
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     8
# Positive    7
# Negative    1
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 5   I tested MSI Claw 8 AI+ and compared it agains...               0.5574
# 10  Google Pixel 10's GPU might come courtesy of I...               0.3612
# 1   TSMC’s 2nm Trial Production Yields are now Wel...               0.2732
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 13  GPU maker Imagination may have accidentally co...                -0.34
# 0   President Trump Positions U.S. as Global Super...                 0.00
# 4                      (ITmedia, 3/17) 鴻激キゃ荀帥筝綽綺取 ...                 0.00
#
# ==================================================
# Processing Tesla...
#
# Sentiment Analysis Summary for Tesla:
# Articles analyzed: 100
# Average Raw Sentiment: -0.1312
# Average Processed Sentiment: -0.1426
# Combined Average Sentiment: -0.1369
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Negative    53
# Neutral     31
# Positive    16
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 99  Yes, Morgan Freeman once said he was a 'huge f...               0.8402
# 26  Beloved LA restaurant hit with social media ba...               0.7717
# 56  Trump showed up at the Wrestling Championships...               0.7579
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 55  Domestic patriot in a SUV tries to take out a ...              -0.8176
# 32  The Tesla Cybertruck design disaster just keep...              -0.8020
# 91  "Hateful, Violent": Tesla Cybertrucks Vandalis...              -0.7964
#
# ==================================================
# Processing Walmart...
#
# Sentiment Analysis Summary for Walmart:
# Articles analyzed: 97
# Average Raw Sentiment: 0.2972
# Average Processed Sentiment: 0.2951
# Combined Average Sentiment: 0.2962
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    76
# Negative    14
# Neutral      7
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 34  Walmart Super Savings Week: Best Early Deals o...               0.8442
# 54  Best Buy takes on Walmart, Amazon in billion-d...               0.8271
# 65  Duck MAX Strength Packing Tape Refill 6-Pack f...               0.7579
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 68  Celeste Gay: Struggling actress posted a video...              -0.6808
# 29  The Apple Watch Series 10 is on sale for its l...              -0.3818
# 61  Why companies are quietly abandoning their cli...              -0.3818
#
# ==================================================
# Processing Visa...
#
# Sentiment Analysis Summary for Visa:
# Articles analyzed: 97
# Average Raw Sentiment: 0.0585
# Average Processed Sentiment: 0.0617
# Combined Average Sentiment: 0.0601
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    52
# Negative    29
# Neutral     16
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 66  Ending Soon! Support The Florida Ozer Center A...               0.9273
# 70  Shohei Ohtani gets the best homecoming gift af...               0.7964
# 14  To safeguard digital sovereignty, India should...               0.7783
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 87  Believe It Or Not, Dems Are Actually Angry Tru...              -0.9246
# 43  Vehicle Owner Demanded To Be Reimbursed For Hi...              -0.9209
# 85  More Migrant Murderers: Stephen Miller Says Bi...              -0.8744
#
# ==================================================
# Processing JPMorgan...
#
# Sentiment Analysis Summary for JPMorgan:
# Articles analyzed: 100
# Average Raw Sentiment: 0.4033
# Average Processed Sentiment: 0.4299
# Combined Average Sentiment: 0.4166
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    91
# Negative     6
# Neutral      3
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 57  Kratos Defense & Security Solutions, Inc. (NAS...               0.7003
# 58  Starwood Property Trust, Inc. (NYSE:STWD) Shar...               0.6705
# 46  6,385 Shares in JPMorgan Chase & Co. (NYSE:JPM...               0.6597
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 15  Is Frank founder Charlie Javice a genius or a ...              -0.5859
# 16  Is Frank founder Charlie Javice a genius or a ...              -0.5859
# 17  Is Frank founder Charlie Javice a genius or a ...              -0.5859
#
# ==================================================
# Processing Tencent...
#
# Sentiment Analysis Summary for Tencent:
# Articles analyzed: 100
# Average Raw Sentiment: 0.0356
# Average Processed Sentiment: 0.0373
# Combined Average Sentiment: 0.0364
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     98
# Positive     2
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                title  title_sentiment_raw
# 0  Alphabet (GOOGL) Strengthens AI and Cloud Secu...               0.6597
# 1            tencentcloud-sdk-python-yunsou 3.0.1346               0.0000
# 2           tencentcloud-sdk-python-yunjing 3.0.1346               0.0000
#
# Most Negative Headlines:
#                                       title  title_sentiment_raw
# 1   tencentcloud-sdk-python-yunsou 3.0.1346                  0.0
# 2  tencentcloud-sdk-python-yunjing 3.0.1346                  0.0
# 3  tencentcloud-sdk-python-youmall 3.0.1346                  0.0
#
# ==================================================
# Processing United Health...
#
# Sentiment Analysis Summary for United Health:
# Articles analyzed: 96
# Average Raw Sentiment: -0.0095
# Average Processed Sentiment: -0.0202
# Combined Average Sentiment: -0.0148
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    41
# Negative    39
# Neutral     16
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 61  Gender Parity At Work: 9 Ways Women Can Redefi...               0.8176
# 72  A Certain Kind of TV Show Is More Popular Than...               0.7713
# 63  Venezuela to Accept US Deportees in Win for Do...               0.7506
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 13  When cancer treatment goes wrong: An irreversi...              -0.9231
# 3   50,000 killed in Gaza since start of Israel-Ha...              -0.8555
# 27  50,000 killed in Gaza since start of Israel-Ha...              -0.8555
#
# ==================================================
# Processing Costco...
#
# Sentiment Analysis Summary for Costco:
# Articles analyzed: 48
# Average Raw Sentiment: 0.2164
# Average Processed Sentiment: 0.1657
# Combined Average Sentiment: 0.1910
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    30
# Negative     9
# Neutral      9
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 26  The "Beautiful" Stoneware Dinner Set Everyone ...               0.8316
# 34  ‘If you want to make sure your Cheez-Its are t...               0.7906
# 22  China’s largest shipping line sees stunning ga...               0.7845
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 35  Costco follows Walmart, a weight loss drug pan...              -0.8442
# 41  Stifel Nicolaus Issues Pessimistic Forecast fo...              -0.3612
# 6   Segway Recalls 220,000 Scooters After Folding ...              -0.3400
#
# ==================================================
# Processing Netflix...
#
# Sentiment Analysis Summary for Netflix:
# Articles analyzed: 94
# Average Raw Sentiment: 0.1670
# Average Processed Sentiment: 0.1781
# Combined Average Sentiment: 0.1726
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    52
# Neutral     27
# Negative    15
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 47  ‘The Residence’ Creator on Casting Al Franken ...               0.8622
# 35  Conan O'Brien to be Honored With Coveted Mark ...               0.8481
# 21  Daredevil: Born Again Is Fantastic, But I'm Su...               0.8477
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 13  Netflix to Offer Prince Harry and Meghan Markl...              -0.5994
# 22  Prince Harry 'offered new Netflix series' on P...              -0.5994
# 44  Taylor Sheridan And Chris Hemsworth Crossed Pa...              -0.5994
#
# ==================================================
# Processing Johnson & Johnson...
#
# Sentiment Analysis Summary for Johnson & Johnson:
# Articles analyzed: 93
# Average Raw Sentiment: 0.0606
# Average Processed Sentiment: 0.0653
# Combined Average Sentiment: 0.0629
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    43
# Negative    28
# Neutral     22
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 47  Max Frankel, Holocaust survivor and Pulitzer P...               0.8625
# 52  ‘The Residence’ Creator on Casting Al Franken ...               0.8622
# 29  Inside Florida's comeback over UConn: How Walt...               0.7845
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 1   Dan Hurley is sad, frustrated and 'f---ing dra...              -0.8834
# 75  The Nazis Made A Horrifying Move In 1933. I'm ...              -0.8271
# 14  Anger, frustration, sadness and pride: Dan Hur...              -0.8074
#
# ==================================================
# Processing Novo Nordisk...
#
# Sentiment Analysis Summary for Novo Nordisk:
# Articles analyzed: 8
# Average Raw Sentiment: 0.2089
# Average Processed Sentiment: 0.2300
# Combined Average Sentiment: 0.2195
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    4
# Neutral     2
# Negative    2
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                title  title_sentiment_raw
# 1  NVO FINAL DEADLINE: ROSEN, NATIONAL TRIAL LAWY...               0.8074
# 0  NVO INVESTOR ALERT: Bronstein, Gewirtz & Gross...               0.4466
# 5          Growth Stocks To Watch Today – March 21st               0.3818
#
# Most Negative Headlines:
#                                                title  title_sentiment_raw
# 6  Novo Nordisk (NVO) Faces Securities Class Acti...              -0.4019
# 2  SHAREHOLDER ACTION REMINDER: Faruqi & Faruqi, ...               0.0000
# 3  Was Jim Cramer Right About Eli Lilly and Compa...               0.0000
#
# ==================================================
# Processing Alibaba...
#
# Sentiment Analysis Summary for Alibaba:
# Articles analyzed: 13
# Average Raw Sentiment: 0.1652
# Average Processed Sentiment: 0.1895
# Combined Average Sentiment: 0.1774
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    8
# Neutral     3
# Negative    2
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 0        SECURITY AFFAIRS MALWARE NEWSLETTER ROUND 38               0.4824
# 10  Promising Digital Media Stocks To Research – M...               0.4019
# 1   Security Affairs newsletter Round 516 by Pierl...               0.3400
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 12  Zero-day broker Operation Zero offers up to $4...              -0.3400
# 3          UAT-5918 ATP group targets critical Taiwan              -0.3182
# 2   As investors hunt for reasons to sell stocks, ...               0.0000
#
# ==================================================
# Processing Hermes...
#
# Sentiment Analysis Summary for Hermes:
# Articles analyzed: 5
# Average Raw Sentiment: 0.1842
# Average Processed Sentiment: 0.1790
# Combined Average Sentiment: 0.1816
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    3
# Neutral     2
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                title  title_sentiment_raw
# 4  Musical uses unusual audition process to power...               0.4215
# 0                               node-hermes-qt 1.3.0               0.0000
# 1                                       Weekend 3.22               0.0000
#
# Most Negative Headlines:
#                                                title  title_sentiment_raw
# 3  Wedbush Issues Negative Forecast for CAVA Grou...              -0.5719
# 0                               node-hermes-qt 1.3.0               0.0000
# 1                                       Weekend 3.22               0.0000
#
# ==================================================
# Processing Nestle...
#
# Sentiment Analysis Summary for Nestle:
# Articles analyzed: 8
# Average Raw Sentiment: 0.1607
# Average Processed Sentiment: 0.1685
# Combined Average Sentiment: 0.1646
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    4
# Negative    4
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                title  title_sentiment_raw
# 0   Chelsea edge Man City; Wins for Man United, L...               0.7579
# 3     West Ham leapfrog Tottenham with WSL derby win               0.5859
# 7  Hillingdon celebrates 60 years as a London bor...               0.5719
#
# Most Negative Headlines:
#                                                title  title_sentiment_raw
# 6  Hindustan Unilever, Nestle, Britannia Industri...              -0.6249
# 1  Ireland v Bulgaria: Boys in Green fall behind ...              -0.3412
# 4  A movement to ban food dyes gains ground acros...              -0.2732
#
# ==================================================
# Processing Cisco...
#
# Sentiment Analysis Summary for Cisco:
# Articles analyzed: 12
# Average Raw Sentiment: 0.1065
# Average Processed Sentiment: 0.1489
# Combined Average Sentiment: 0.1277
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    6
# Neutral     4
# Negative    2
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                title  title_sentiment_raw
# 1       SECURITY AFFAIRS MALWARE NEWSLETTER ROUND 38               0.4824
# 2  Security Affairs newsletter Round 516 by Pierl...               0.3400
# 7  U.S. Treasury removed sanctions against the cr...               0.2023
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 0   If Trump Destroys Inflation Reduction Act, Eco...              -0.5574
# 11  Zero-day broker Operation Zero offers up to $4...              -0.3400
# 3          UAT-5918 ATP group targets critical Taiwan              -0.3182
#
# ==================================================
# Processing Palantir...
#
# Sentiment Analysis Summary for Palantir:
# Articles analyzed: 11
# Average Raw Sentiment: 0.1245
# Average Processed Sentiment: 0.1216
# Combined Average Sentiment: 0.1230
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    7
# Negative    2
# Neutral     2
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                title  title_sentiment_raw
# 2  Better Artificial Intelligence Stock: BigBear....               0.7184
# 6  Is Palantir Technologies Inc. (PLTR) The Best ...               0.6369
# 0  Should You Buy Stocks in the Nasdaq Correction...               0.3818
#
# Most Negative Headlines:
#                                                title  title_sentiment_raw
# 5       MAGA Must Resolve Tech vs. Populist Tensions              -0.0258
# 3  Palantir Stock vs. Nvidia Stock: Wall Street S...               0.0000
# 7  Opinion | Stanford students sell their souls f...               0.0000

# %%
# Display final comparison
print("\n\n" + "="*70)
print("FINAL COMPANY SENTIMENT COMPARISON")
print("="*70)

# Sort by combined sentiment for better visualization
sorted_summary = summary_results.sort_values(by='combined_sentiment', ascending=False)

# Display company comparison
print(sorted_summary[['company', 'articles_count', 'combined_sentiment', 'predicted_movement']])

# Calculate market-wide sentiment
valid_results = summary_results.dropna(subset=['combined_sentiment'])
if len(valid_results) > 0:
    market_sentiment = valid_results['combined_sentiment'].mean()
    print(f"\nOverall Market Sentiment: {market_sentiment:.4f}")
    print(f"Market Direction Prediction: {predict_movement(market_sentiment)}")

print(f"\nDetailed results saved to: {results_dir}")
print(f"Summary comparison saved to: {summary_filepath}")
# Out:
# ======================================================================
# FINAL COMPANY SENTIMENT COMPARISON
# ======================================================================
#               company articles_count  combined_sentiment predicted_movement
# 7            JPMorgan            100            0.416610                 UP
# 5             Walmart             97            0.296198                 UP
# 13       Novo Nordisk              8            0.219463                 UP
# 1           Microsoft             98            0.204575                 UP
# 10             Costco             48            0.191026                 UP
# 2              Nvidia             99            0.188898                 UP
# 0               Apple             97            0.185187                 UP
# 15             Hermes              5            0.181586                 UP
# 14            Alibaba             13            0.177379                 UP
# 11            Netflix             94            0.172553                 UP
# 3                TSMC             16            0.170918                 UP
# 16             Nestle              8            0.164606                 UP
# 17              Cisco             12            0.127698            NEUTRAL
# 18           Palantir             11            0.123025            NEUTRAL
# 12  Johnson & Johnson             93            0.062949            NEUTRAL
# 6                Visa             97            0.060118            NEUTRAL
# 8             Tencent            100            0.036420            NEUTRAL
# 9       United Health             96           -0.014822            NEUTRAL
# 4               Tesla            100           -0.136913            NEUTRAL
#
# Overall Market Sentiment: 0.1488
# Market Direction Prediction: NEUTRAL
#
# Detailed results saved to: company_sentiment_results
# Summary comparison saved to: company_sentiment_results/all_companies_summary_20250327_124257.csv

# %%
# Import necessary libraries for stock data retrieval
import yfinance as yf
from datetime import datetime, timedelta

# Function to convert company name to ticker symbol
def company_to_ticker(company_name):
    # This is a simple mapping - in a production environment, you might want a more robust solution
    ticker_mapping = {
        "Apple": "AAPL",
        "Microsoft": "MSFT",
        "Nvidia": "NVDA",
        "TSMC": "TSM",
        "Tesla": "TSLA",
        "Walmart": "WMT",
        "Visa": "V",
        "JPMorgan": "JPM",
        "Tencent": "TCEHY",
        "United Health": "UNH",
        "Costco": "COST",
        "Netflix": "NFLX",
        "Johnson & Johnson": "JNJ",
        "Novo Nordisk": "NVO",
        "Alibaba": "BABA",
        "SAP": "SAP",
        "Hermes": "RMS.PA",
        "Nestle": "NSRGY",
        "Cisco": "CSCO",
        "Palantir": "PLTR"
    }

    return ticker_mapping.get(company_name)

# Parse dates
start_date_dt = datetime.strptime(start_date, "%Y-%m-%d")
end_date_dt = datetime.strptime(end_date, "%Y-%m-%d")

# Get the day before start_date and the day after end_date
day_before_start = (start_date_dt - timedelta(days=1)).strftime("%Y-%m-%d")
day_after_end = (end_date_dt + timedelta(days=1)).strftime("%Y-%m-%d")
end=(end_date_dt + timedelta(days=2)).strftime("%Y-%m-%d")

# %%
print("\n\n" + "="*70)
print("PREDICTION VALIDATION AGAINST ACTUAL STOCK MOVEMENT")
print("="*70)

# Filter companies that are not predicted as NEUTRAL and have at least 30 articles
companies_to_check = summary_results[(summary_results['predicted_movement'] != 'NEUTRAL') &
                                    (summary_results['articles_count'] >= 30)]


# Create a DataFrame to store validation results
validation_results = pd.DataFrame(columns=[
    'company', 'ticker', 'prediction', 'before_close',
    'comparison_price', 'actual_movement', 'result'
])

# If no companies match the criteria
if len(companies_to_check) == 0:
    print("No companies match the criteria (non-NEUTRAL prediction with at least 30 articles)")
else:
    # Initialize counters for hit rate calculation
    total_checks = 0
    total_hits = 0

    # Check each qualifying company
    for index, row in companies_to_check.iterrows():
        company_name = row['company']
        prediction = row['predicted_movement']

        # Get ticker for the company
        ticker = company_to_ticker(company_name)
        if ticker:
            try:
                # Get stock data for the day before start_date
                before_data = yf.download(ticker, start=day_before_start, end=start_date, progress=False)
                # Get stock data for the day after end_date
                after_data = yf.download(ticker, start=end_date, end=end, progress=False)

                if not before_data.empty and not after_data.empty:
                    # Get close price from day before start_date
                    close_price = before_data.iloc[0]['Close'].item()

                    # For UP predictions, use the high price
                    # For DOWN predictions, use the low price
                    if prediction == "UP":
                        comparison_price = after_data.iloc[0]['High'].item()
                        actual_movement = "UP" if comparison_price > close_price else "DOWN"
                    else:  # prediction == "DOWN"
                        comparison_price = after_data.iloc[0]['Low'].item()
                        actual_movement = "DOWN" if comparison_price < close_price else "UP"

                    # Compare with prediction
                    result = "HIT" if prediction == actual_movement else "MISS"

                    # Update counters
                    total_checks += 1
                    if result == "HIT":
                        total_hits += 1

                    # Add to validation results
                    new_row = {
                        'company': company_name,
                        'ticker': ticker,
                        'prediction': prediction,
                        'before_close': close_price,
                        'comparison_price': comparison_price,  # Changed from 'after_high'
                        'actual_movement': actual_movement,
                        'result': result
                    }
                    validation_results = pd.concat([validation_results, pd.DataFrame([new_row])], ignore_index=True)
                else:
                    print(f"{company_name} ({ticker}): Insufficient stock data available")

            except Exception as e:
                print(f"{company_name} ({ticker}): Error retrieving stock data - {str(e)}")
        else:
            print(f"{company_name}: No ticker symbol mapping available")


        # Calculate and print hit rate
        if total_checks > 0:
            hit_rate = (total_hits / total_checks) * 100
            validation_results.attrs['hit_rate'] = hit_rate
        else:
            print("\nNo valid stock data was available for comparison")

    # Save the validation results
    print(validation_results)
    print(f"Total predictions checked: {total_checks}")
    print(f"Total hits: {total_hits}")
    print(f"Hit rate: {hit_rate:.2f}%")
# Out:
# ======================================================================
# PREDICTION VALIDATION AGAINST ACTUAL STOCK MOVEMENT
# ======================================================================
# YF.download() has changed argument auto_adjust default to True
# <ipython-input-10-fb81de5bc027>:69: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   validation_results = pd.concat([validation_results, pd.DataFrame([new_row])], ignore_index=True)
#      company ticker prediction  before_close  comparison_price  \
# 0      Apple   AAPL         UP    218.270004        221.479996
# 1  Microsoft   MSFT         UP    391.260010        395.399994
# 2     Nvidia   NVDA         UP    117.699997        122.220001
# 3    Walmart    WMT         UP     85.980003         87.650002
# 4   JPMorgan    JPM         UP    241.630005        248.690002
# 5     Costco   COST         UP    909.260010        928.650024
# 6    Netflix   NFLX         UP    960.289978        977.000000
#
#   actual_movement result
# 0              UP    HIT
# 1              UP    HIT
# 2              UP    HIT
# 3              UP    HIT
# 4              UP    HIT
# 5              UP    HIT
# 6              UP    HIT
# Total predictions checked: 7
# Total hits: 7
# Hit rate: 100.00%
