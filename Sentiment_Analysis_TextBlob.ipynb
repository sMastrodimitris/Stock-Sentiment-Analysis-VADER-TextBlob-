# %%
import requests
import json
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob
import os
from datetime import datetime
import yfinance as yf
from datetime import datetime, timedelta

# %%
# Download NLTK resources (only need to run once)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# NewsAPI parameters
api_key = ""  # Replace with your actual NewsAPI key
companies = [
    "Apple", "Microsoft", "Nvidia", "TSMC", "Tesla",
    "Walmart", "Visa", "JPMorgan", "Tencent", "United Health",
    "Costco", "Netflix", "Johnson & Johnson", "Novo Nordisk",
    "Alibaba", "Hermes", "Nestle", "Cisco", "Palantir"
]
start_date = "2025-03-22"
end_date = "2025-03-23"

# Create a directory for results if it doesn't exist
results_dir = "company_sentiment_results"
os.makedirs(results_dir, exist_ok=True)

# Summary DataFrame to store aggregate results for all companies
summary_results = pd.DataFrame(columns=[
    'company', 'articles_count', 'avg_sentiment_raw',
    'avg_sentiment_processed', 'combined_sentiment', 'predicted_movement',
    'positive_count', 'neutral_count', 'negative_count'
])

# %%
# Preprocessing function
def preprocess_text(text):
    if pd.isna(text):
        return ""

    # Convert to lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)

    # Remove special characters and numbers
    text = re.sub(r'\@\w+|\#|\d+', '', text)

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Tokenize
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    # Join tokens back into text
    processed_text = ' '.join(tokens)

    return processed_text

# Function to get sentiment scores using TextBlob
def analyze_sentiment(text):
    if pd.isna(text) or text == "":
        return 0  # neutral score for empty text

    # Get sentiment using TextBlob (polarity ranges from -1 to 1)
    blob = TextBlob(text)
    return blob.sentiment.polarity


##########################################0.15 -> 0.1
# Categorize sentiment
def categorize_sentiment(score):
    if score >= 0.1:
        return 'Positive'
    elif score <= -0.1:
        return 'Negative'
    else:
        return 'Neutral'

# Function to predict market movement
def predict_movement(score):
    if score > 0.1:
        return "UP"
    elif score < -0.1:
        return "DOWN"
    else:
        return "NEUTRAL"

# Function to convert company name to ticker symbol
def company_to_ticker(company_name):
    # This is a simple mapping - in a production environment, you might want a more robust solution
    ticker_mapping = {
        "Apple": "AAPL",
        "Microsoft": "MSFT",
        "Nvidia": "NVDA",
        "TSMC": "TSM",
        "Tesla": "TSLA",
        "Walmart": "WMT",
        "Visa": "V",
        "JPMorgan": "JPM",
        "Tencent": "TCEHY",
        "United Health": "UNH",
        "Costco": "COST",
        "Netflix": "NFLX",
        "Johnson & Johnson": "JNJ",
        "Novo Nordisk": "NVO",
        "Alibaba": "BABA",
        "SAP": "SAP",
        "Hermes": "RMS.PA",
        "Nestle": "NSRGY",
        "Cisco": "CSCO",
        "Palantir": "PLTR"
    }

    return ticker_mapping.get(company_name)

# %%
# Process each company
for company in companies:
    print(f"\n{'='*50}")
    print(f"Processing {company}...")

    # NewsAPI endpoint
    url = f"https://newsapi.org/v2/everything?q={company}&from={start_date}&to={end_date}&language=en&sortBy=publishedAt&apiKey={api_key}"

    # Make the request
    response = requests.get(url)
    data = response.json()

    # Process the results
    if data['status'] == 'ok' and len(data.get('articles', [])) > 0:
        # Create a list to store article data
        articles_data = []

        for article in data['articles']:
            article_info = {
                'title': article.get('title', ''),
                'description': article.get('description', ''),
                'content': article.get('content', ''),
                'url': article.get('url', ''),
                'publishedAt': article.get('publishedAt', '')
            }
            articles_data.append(article_info)

        # Convert to DataFrame
        df = pd.DataFrame(articles_data)

        # Apply preprocessing to text columns
        df['processed_title'] = df['title'].apply(preprocess_text)
        df['processed_description'] = df['description'].apply(preprocess_text)
        df['processed_content'] = df['content'].apply(preprocess_text)

        # Apply sentiment analysis on both raw and processed text
        # Raw text sentiment analysis
        df['title_sentiment_raw'] = df['title'].apply(analyze_sentiment)
        df['description_sentiment_raw'] = df['description'].apply(analyze_sentiment)
        df['content_sentiment_raw'] = df['content'].apply(analyze_sentiment)

        # Processed text sentiment analysis
        df['title_sentiment_processed'] = df['processed_title'].apply(analyze_sentiment)
        df['description_sentiment_processed'] = df['processed_description'].apply(analyze_sentiment)
        df['content_sentiment_processed'] = df['processed_content'].apply(analyze_sentiment)

        # Calculate weighted average sentiment
        df['overall_sentiment_raw'] = (
            df['title_sentiment_raw'] * 0.5 +
            df['description_sentiment_raw'] * 0.4 +
            df['content_sentiment_raw'] * 0.1
        )

        df['overall_sentiment_processed'] = (
            df['title_sentiment_processed'] * 0.5 +
            df['description_sentiment_processed'] * 0.4 +
            df['content_sentiment_processed'] * 0.1
        )

        # Categorize sentiment
        df['sentiment_category_raw'] = df['overall_sentiment_raw'].apply(categorize_sentiment)
        df['sentiment_category_processed'] = df['overall_sentiment_processed'].apply(categorize_sentiment)

        # Save detailed results for this company
        company_filename = f"{company.replace(' ', '_').lower()}_sentiment_{start_date}_to_{end_date}.csv"
        company_filepath = os.path.join(results_dir, company_filename)
        df.to_csv(company_filepath, index=False)

        # Calculate summary metrics
        raw_avg = df['overall_sentiment_raw'].mean()
        processed_avg = df['overall_sentiment_processed'].mean()
        combined_avg = (raw_avg + processed_avg) / 2
        sentiment_prediction = predict_movement(combined_avg)

        # Count sentiment categories
        sentiment_counts = df['sentiment_category_processed'].value_counts()
        positive_count = sentiment_counts.get('Positive', 0)
        neutral_count = sentiment_counts.get('Neutral', 0)
        negative_count = sentiment_counts.get('Negative', 0)

        # Add to summary results
        summary_results = pd.concat([summary_results, pd.DataFrame([{
            'company': company,
            'articles_count': len(df),
            'avg_sentiment_raw': raw_avg,
            'avg_sentiment_processed': processed_avg,
            'combined_sentiment': combined_avg,
            'predicted_movement': sentiment_prediction,
            'positive_count': positive_count,
            'neutral_count': neutral_count,
            'negative_count': negative_count
        }])], ignore_index=True)

        # Display summary for this company
        print(f"\nSentiment Analysis Summary for {company}:")
        print(f"Articles analyzed: {len(df)}")
        print(f"Average Raw Sentiment: {raw_avg:.4f}")
        print(f"Average Processed Sentiment: {processed_avg:.4f}")
        print(f"Combined Average Sentiment: {combined_avg:.4f}")
        print(f"Predicted Market Movement: {sentiment_prediction}")

        # Display sentiment distribution
        print("\nSentiment Distribution:")
        print(df['sentiment_category_processed'].value_counts())

        # Display most positive/negative headlines
        print("\nMost Positive Headlines:")
        print(df.nlargest(3, 'title_sentiment_raw')[['title', 'title_sentiment_raw']])

        print("\nMost Negative Headlines:")
        print(df.nsmallest(3, 'title_sentiment_raw')[['title', 'title_sentiment_raw']])

    else:
        print(f"Error retrieving data for {company}: {data.get('message', 'Unknown error')}")
        # Add empty row to summary with error indication
        summary_results = pd.concat([summary_results, pd.DataFrame([{
            'company': company,
            'articles_count': 0,
            'avg_sentiment_raw': None,
            'avg_sentiment_processed': None,
            'combined_sentiment': None,
            'predicted_movement': 'ERROR',
            'positive_count': 0,
            'neutral_count': 0,
            'negative_count': 0
        }])], ignore_index=True)

# Save summary results
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
summary_filepath = os.path.join(results_dir, f"all_companies_summary_{timestamp}.csv")
summary_results.to_csv(summary_filepath, index=False)
# Out:
# ==================================================
# Processing Apple...
# <ipython-input-5-59b6be752eb2>:82: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_results = pd.concat([summary_results, pd.DataFrame([{
# Sentiment Analysis Summary for Apple:
# Articles analyzed: 97
# Average Raw Sentiment: 0.0859
# Average Processed Sentiment: 0.0680
# Combined Average Sentiment: 0.0769
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     50
# Positive    36
# Negative    11
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 27  Adam Scott Describes Fan Commitment to ‘Severa...                  0.7
# 64          7 Must-See Shows If You Loved The Expanse                  0.7
# 5   Is This Why So Many People Are Switching To Wi...                  0.5
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 2   Euphoria star Austin Abrams eyed for Resident ...                 -1.0
# 34  Apple Maps bug randomly showing airport baggag...                 -0.5
# 77  Gel’s Streaming Accounts Got Hacked With Some ...                 -0.5
#
# ==================================================
# Processing Microsoft...
#
# Sentiment Analysis Summary for Microsoft:
# Articles analyzed: 98
# Average Raw Sentiment: 0.1018
# Average Processed Sentiment: 0.0865
# Combined Average Sentiment: 0.0941
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     55
# Positive    35
# Negative     8
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 16  8 awesome and little-known Android app you sho...                  1.0
# 51  Switch 2 Will Be Nintendo's Best Ever Console ...                  1.0
# 17  Microsoft selloff brings attractive risk/rewar...                  0.8
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 70  Jensen Huang's quantum mea culpa didn't convin...                 -0.7
# 45  3 times Microsoft has tried (and failed) to re...                 -0.5
# 61  Why India needs a strategic cryptocurrency res...                 -0.3
#
# ==================================================
# Processing Nvidia...
#
# Sentiment Analysis Summary for Nvidia:
# Articles analyzed: 99
# Average Raw Sentiment: 0.0539
# Average Processed Sentiment: 0.0557
# Combined Average Sentiment: 0.0548
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     51
# Positive    36
# Negative    12
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 89  Is NVIDIA Corporation (NVDA) The Best Stock to...                  1.0
# 22  Asus debuts its own mini AI supercomputer: Asc...                  0.6
# 72  How to invest in this market sell-off, accordi...                  0.5
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 56  Jensen Huang's quantum mea culpa didn't convin...                 -0.7
# 59  Jensen Huang's quantum mea culpa didn't convin...                 -0.7
# 41  This Nvidia-Backed Artificial Intelligence (AI...                 -0.3
#
# ==================================================
# Processing TSMC...
#
# Sentiment Analysis Summary for TSMC:
# Articles analyzed: 16
# Average Raw Sentiment: 0.0879
# Average Processed Sentiment: 0.0727
# Combined Average Sentiment: 0.0803
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     11
# Positive     5
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 13  GPU maker Imagination may have accidentally co...             0.400000
# 15  Semi Country excerpt 2: The unique 'Taiwan' ad...             0.375000
# 6   The week in chip news: Nvidia's GTC 2025 blitz...             0.136364
#
# Most Negative Headlines:
#                                                title  title_sentiment_raw
# 7  Apple Expected to Launch iPhones with 2nm Chip...                 -0.1
# 0  President Trump Positions U.S. as Global Super...                  0.0
# 1  TSMC’s 2nm Trial Production Yields are now Wel...                  0.0
#
# ==================================================
# Processing Tesla...
#
# Sentiment Analysis Summary for Tesla:
# Articles analyzed: 100
# Average Raw Sentiment: 0.0206
# Average Processed Sentiment: 0.0062
# Combined Average Sentiment: 0.0134
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     66
# Positive    19
# Negative    15
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 17  Survey: Best electric vehicles for families re...                  1.0
# 18  From President Trump to Global Affairs – The W...                  0.5
# 56  Trump showed up at the Wrestling Championships...                  0.5
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 9   s This a Joke Too, Tim? Check Out the Violent ...                 -0.8
# 34  Jeremy Clarkson taunts 'idiot' Elon Musk over ...                 -0.8
# 37  Jeremy Clarkson taunts ‘idiot’ Elon Musk over ...                 -0.8
#
# ==================================================
# Processing Walmart...
#
# Sentiment Analysis Summary for Walmart:
# Articles analyzed: 97
# Average Raw Sentiment: 0.1108
# Average Processed Sentiment: 0.1060
# Combined Average Sentiment: 0.1084
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    47
# Neutral     36
# Negative    14
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 2   Best Buy Courts Influencers to Tap $32 Billion...                  1.0
# 3   Best Buy Courts Influencers to Tap $32 Billion...                  1.0
# 54  Best Buy takes on Walmart, Amazon in billion-d...                  1.0
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 23  100-Oz TIKI BiteFighter Mosquito Repellent Tor...                 -0.9
# 55  Walmart - TIKI 100oz BiteFighter Mosquito Repe...                 -0.9
# 72  Reviewers Are 'Shocked At The Quality' Of This...                 -0.7
#
# ==================================================
# Processing Visa...
#
# Sentiment Analysis Summary for Visa:
# Articles analyzed: 97
# Average Raw Sentiment: 0.0623
# Average Processed Sentiment: 0.0638
# Combined Average Sentiment: 0.0631
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     54
# Positive    30
# Negative    13
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 20  Is Visa Inc. (V)The Best Stock to Buy Accordin...                  1.0
# 70  Shohei Ohtani gets the best homecoming gift af...                  1.0
# 92  What Happened To Ashley Michelle & Manuel Vele...                  0.8
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 0                             Questionable governance              -0.5000
# 87  Believe It Or Not, Dems Are Actually Angry Tru...              -0.3625
# 43  Vehicle Owner Demanded To Be Reimbursed For Hi...              -0.3500
#
# ==================================================
# Processing JPMorgan...
#
# Sentiment Analysis Summary for JPMorgan:
# Articles analyzed: 100
# Average Raw Sentiment: 0.0880
# Average Processed Sentiment: 0.0615
# Combined Average Sentiment: 0.0747
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     70
# Positive    27
# Negative     3
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 85  Natixis Advisors LLC Raises Holdings in CCC In...                  0.8
# 2   Is JPMorgan Chase & Co. (JPM) the Most Underva...                  0.5
# 6   Top analysts are upbeat on these 3 dividend st...                  0.5
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 38  Natixis Advisors LLC Has $3.15 Million Positio...            -0.166667
# 81  HighTower Advisors LLC Has $2.60 Million Posit...            -0.166667
# 8   Tesla's stock is down for the ninth week in a ...            -0.085185
#
# ==================================================
# Processing Tencent...
#
# Sentiment Analysis Summary for Tencent:
# Articles analyzed: 100
# Average Raw Sentiment: -0.0124
# Average Processed Sentiment: -0.0124
# Combined Average Sentiment: -0.0124
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral    100
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                title  title_sentiment_raw
# 0  Alphabet (GOOGL) Strengthens AI and Cloud Secu...                  0.0
# 1            tencentcloud-sdk-python-yunsou 3.0.1346                  0.0
# 2           tencentcloud-sdk-python-yunjing 3.0.1346                  0.0
#
# Most Negative Headlines:
#                                                title  title_sentiment_raw
# 0  Alphabet (GOOGL) Strengthens AI and Cloud Secu...                  0.0
# 1            tencentcloud-sdk-python-yunsou 3.0.1346                  0.0
# 2           tencentcloud-sdk-python-yunjing 3.0.1346                  0.0
#
# ==================================================
# Processing United Health...
#
# Sentiment Analysis Summary for United Health:
# Articles analyzed: 96
# Average Raw Sentiment: 0.0515
# Average Processed Sentiment: 0.0307
# Combined Average Sentiment: 0.0411
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     53
# Positive    29
# Negative    14
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 58  Manchester United’s Sir Jim Ratcliffe’s Brave ...                 0.80
# 63  Venezuela to Accept US Deportees in Win for Do...                 0.80
# 61  Gender Parity At Work: 9 Ways Women Can Redefi...                 0.55
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 59       An ‘Impossible’ Disease Outbreak in the Alps            -0.666667
# 2   Grieving families join Andrew Cuomo’s mayoral ...            -0.658333
# 4             The Meager Agenda of Abundance Liberals            -0.600000
#
# ==================================================
# Processing Costco...
#
# Sentiment Analysis Summary for Costco:
# Articles analyzed: 48
# Average Raw Sentiment: 0.0773
# Average Processed Sentiment: 0.0786
# Combined Average Sentiment: 0.0779
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    20
# Neutral     20
# Negative     8
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 26  The "Beautiful" Stoneware Dinner Set Everyone ...                0.725
# 11  Costco Members Are Thrilled With 'Huge' Announ...                0.500
# 12  All the best EV (and PHEV) cash back deals we ...                0.500
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 35  Costco follows Walmart, a weight loss drug pan...            -0.500000
# 20  ‘One of these is a scam’: Costco shopper reach...            -0.145833
# 3   Segway recalls 220,000 of its scooters due to ...            -0.125000
#
# ==================================================
# Processing Netflix...
#
# Sentiment Analysis Summary for Netflix:
# Articles analyzed: 94
# Average Raw Sentiment: 0.1256
# Average Processed Sentiment: 0.1148
# Combined Average Sentiment: 0.1202
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     47
# Positive    40
# Negative     7
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 19    The Best Movie Of 2024 Is Now Streaming On Hulu                  1.0
# 82  After Watching These 5 Alan Ritchson Scenes, I...                  1.0
# 51   5 great TV shows you need to watch in April 2025                  0.8
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 43  Jujutsu Kaisen Has Bad News for Fans Waiting f...            -0.700000
# 18  3 Brutal New Thriller Movies That Were Just Re...            -0.369318
# 8   Andrew Tate targets Tánaiste in scathing post ...            -0.283333
#
# ==================================================
# Processing Johnson & Johnson...
#
# Sentiment Analysis Summary for Johnson & Johnson:
# Articles analyzed: 93
# Average Raw Sentiment: 0.0713
# Average Processed Sentiment: 0.0623
# Combined Average Sentiment: 0.0668
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     51
# Positive    29
# Negative    13
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 41  66 Breathtaking Photos From The 1960s, The Dec...                  1.0
# 19  Incredible Hulk #23 Preview: Hulk vs. Fashion ...                  0.9
# 22  Manchester Storm shutout Cardiff Devils in six...                  0.8
#
# Most Negative Headlines:
#                                                 title  title_sentiment_raw
# 54  Videos of Steph Curry's 'Insane' Shot From Tun...                 -1.0
# 78  Op-ed: The groupthink mind virus has taken ove...                 -1.0
# 64  Parents of children with disabilities fearful ...                 -0.9
#
# ==================================================
# Processing Novo Nordisk...
#
# Sentiment Analysis Summary for Novo Nordisk:
# Articles analyzed: 8
# Average Raw Sentiment: 0.0638
# Average Processed Sentiment: 0.0934
# Combined Average Sentiment: 0.0786
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     4
# Positive    4
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                title  title_sentiment_raw
# 3  Was Jim Cramer Right About Eli Lilly and Compa...             0.285714
# 1  NVO FINAL DEADLINE: ROSEN, NATIONAL TRIAL LAWY...             0.225000
# 0  NVO INVESTOR ALERT: Bronstein, Gewirtz & Gross...             0.100000
#
# Most Negative Headlines:
#                                                title  title_sentiment_raw
# 4  Novo Nordisk A/S (NYSE:NVO) Shares Gap Down – ...            -0.077778
# 5          Growth Stocks To Watch Today – March 21st             0.000000
# 7  StockNews.com Downgrades Novo Nordisk A/S (NYS...             0.000000
#
# ==================================================
# Processing Alibaba...
#
# Sentiment Analysis Summary for Alibaba:
# Articles analyzed: 13
# Average Raw Sentiment: 0.0370
# Average Processed Sentiment: 0.0320
# Combined Average Sentiment: 0.0345
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     9
# Positive    3
# Negative    1
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 12  Zero-day broker Operation Zero offers up to $4...             0.100000
# 10  Promising Digital Media Stocks To Research – M...             0.066667
# 2   As investors hunt for reasons to sell stocks, ...             0.000000
#
# Most Negative Headlines:
#                                                title  title_sentiment_raw
# 7            Improved ways to operate a rude crawler                 -0.3
# 0       SECURITY AFFAIRS MALWARE NEWSLETTER ROUND 38                 -0.2
# 1  Security Affairs newsletter Round 516 by Pierl...                 -0.1
#
# ==================================================
# Processing Hermes...
#
# Sentiment Analysis Summary for Hermes:
# Articles analyzed: 5
# Average Raw Sentiment: 0.0224
# Average Processed Sentiment: 0.0312
# Combined Average Sentiment: 0.0268
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral    5
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                title  title_sentiment_raw
# 4  Musical uses unusual audition process to power...             0.166667
# 0                               node-hermes-qt 1.3.0             0.000000
# 1                                       Weekend 3.22             0.000000
#
# Most Negative Headlines:
#                                                title  title_sentiment_raw
# 3  Wedbush Issues Negative Forecast for CAVA Grou...                 -0.3
# 0                               node-hermes-qt 1.3.0                  0.0
# 1                                       Weekend 3.22                  0.0
#
# ==================================================
# Processing Nestle...
#
# Sentiment Analysis Summary for Nestle:
# Articles analyzed: 8
# Average Raw Sentiment: 0.1456
# Average Processed Sentiment: 0.2008
# Combined Average Sentiment: 0.1732
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Positive    5
# Neutral     3
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                title  title_sentiment_raw
# 3     West Ham leapfrog Tottenham with WSL derby win                  0.8
# 0   Chelsea edge Man City; Wins for Man United, L...                  0.3
# 2  These lights really tie the room together and ...                  0.2
#
# Most Negative Headlines:
#                                                title  title_sentiment_raw
# 4  A movement to ban food dyes gains ground acros...                  0.0
# 6  Hindustan Unilever, Nestle, Britannia Industri...                  0.0
# 7  Hillingdon celebrates 60 years as a London bor...                  0.0
#
# ==================================================
# Processing Cisco...
#
# Sentiment Analysis Summary for Cisco:
# Articles analyzed: 12
# Average Raw Sentiment: 0.0856
# Average Processed Sentiment: 0.0743
# Combined Average Sentiment: 0.0800
# Predicted Market Movement: NEUTRAL
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     10
# Positive     2
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                 title  title_sentiment_raw
# 9   Bengaluru guy dedicates dazzling video to IT w...                 0.75
# 0   If Trump Destroys Inflation Reduction Act, Eco...                 0.20
# 11  Zero-day broker Operation Zero offers up to $4...                 0.10
#
# Most Negative Headlines:
#                                                title  title_sentiment_raw
# 1       SECURITY AFFAIRS MALWARE NEWSLETTER ROUND 38            -0.200000
# 8  Museum digs up Digital Equipment Corporation's...            -0.133333
# 2  Security Affairs newsletter Round 516 by Pierl...            -0.100000
#
# ==================================================
# Processing Palantir...
#
# Sentiment Analysis Summary for Palantir:
# Articles analyzed: 11
# Average Raw Sentiment: 0.1108
# Average Processed Sentiment: 0.1108
# Combined Average Sentiment: 0.1108
# Predicted Market Movement: UP
#
# Sentiment Distribution:
# sentiment_category_processed
# Neutral     6
# Positive    5
# Name: count, dtype: int64
#
# Most Positive Headlines:
#                                                title  title_sentiment_raw
# 6  Is Palantir Technologies Inc. (PLTR) The Best ...                  1.0
# 1            A Tech Billionaire Attacks His Own Kind                  0.6
# 9  Prediction: These 2 AI Stocks Will Be Worth Mo...                  0.3
#
# Most Negative Headlines:
#                                                title  title_sentiment_raw
# 2  Better Artificial Intelligence Stock: BigBear....                -0.05
# 3  Palantir Stock vs. Nvidia Stock: Wall Street S...                 0.00
# 4               Fiery Palantir CEO banks big profits                 0.00

# %%
# Display final comparison
print("\n\n" + "="*70)
print("FINAL COMPANY SENTIMENT COMPARISON")
print("="*70)

# Sort by combined sentiment for better visualization
sorted_summary = summary_results.sort_values(by='combined_sentiment', ascending=False)

# Display company comparison
print(sorted_summary[['company', 'articles_count', 'combined_sentiment', 'predicted_movement']])

# Calculate market-wide sentiment
valid_results = summary_results.dropna(subset=['combined_sentiment'])
if len(valid_results) > 0:
    market_sentiment = valid_results['combined_sentiment'].mean()
    print(f"\nOverall Market Sentiment: {market_sentiment:.4f}")
    print(f"Market Direction Prediction: {predict_movement(market_sentiment)}")

print(f"\nDetailed results saved to: {results_dir}")
print(f"Summary comparison saved to: {summary_filepath}")
# Out:
# ======================================================================
# FINAL COMPANY SENTIMENT COMPARISON
# ======================================================================
#               company articles_count  combined_sentiment predicted_movement
# 16             Nestle              8            0.173193                 UP
# 11            Netflix             94            0.120195                 UP
# 18           Palantir             11            0.110805                 UP
# 5             Walmart             97            0.108415                 UP
# 1           Microsoft             98            0.094148            NEUTRAL
# 3                TSMC             16            0.080293            NEUTRAL
# 17              Cisco             12            0.079959            NEUTRAL
# 13       Novo Nordisk              8            0.078614            NEUTRAL
# 10             Costco             48            0.077948            NEUTRAL
# 0               Apple             97            0.076911            NEUTRAL
# 7            JPMorgan            100            0.074719            NEUTRAL
# 12  Johnson & Johnson             93            0.066786            NEUTRAL
# 6                Visa             97            0.063081            NEUTRAL
# 2              Nvidia             99            0.054787            NEUTRAL
# 9       United Health             96            0.041120            NEUTRAL
# 14            Alibaba             13            0.034492            NEUTRAL
# 15             Hermes              5            0.026833            NEUTRAL
# 4               Tesla            100            0.013371            NEUTRAL
# 8             Tencent            100           -0.012406            NEUTRAL
#
# Overall Market Sentiment: 0.0718
# Market Direction Prediction: NEUTRAL
#
# Detailed results saved to: company_sentiment_results
# Summary comparison saved to: company_sentiment_results/all_companies_summary_20250327_124308.csv

# %%
# Parse dates
start_date_dt = datetime.strptime(start_date, "%Y-%m-%d")
end_date_dt = datetime.strptime(end_date, "%Y-%m-%d")

# Get the day before start_date and the day after end_date
day_before_start = (start_date_dt - timedelta(days=1)).strftime("%Y-%m-%d")
day_after_end = (end_date_dt + timedelta(days=1)).strftime("%Y-%m-%d")
end = (end_date_dt + timedelta(days=2)).strftime("%Y-%m-%d")

# %%
print("\n\n" + "="*70)
print("PREDICTION VALIDATION AGAINST ACTUAL STOCK MOVEMENT")
print("="*70)

# Filter companies that are not predicted as NEUTRAL and have at least 30 articles
companies_to_check = summary_results[(summary_results['predicted_movement'] != 'NEUTRAL') &
                                    (summary_results['articles_count'] >= 30)]

# Create a DataFrame to store validation results
validation_results = pd.DataFrame(columns=[
    'company', 'ticker', 'prediction', 'before_close',
    'comparison_price', 'actual_movement', 'result'
])

# If no companies match the criteria
if len(companies_to_check) == 0:
    print("No companies match the criteria (non-NEUTRAL prediction with at least 30 articles)")
else:
    # Initialize counters for hit rate calculation
    total_checks = 0
    total_hits = 0

    # Check each qualifying company
    for index, row in companies_to_check.iterrows():
        company_name = row['company']
        prediction = row['predicted_movement']

        # Get ticker for the company
        ticker = company_to_ticker(company_name)
        if ticker:
            try:
                # Get stock data for the day before start_date
                before_data = yf.download(ticker, start=day_before_start, end=start_date, progress=False)
                # Get stock data for the day after end_date
                after_data = yf.download(ticker, start=end_date, end=end, progress=False)

                if not before_data.empty and not after_data.empty:
                    # Get close price from day before start_date
                    close_price = before_data.iloc[0]['Close'].item()

                    # For UP predictions, use the high price
                    # For DOWN predictions, use the low price
                    if prediction == "UP":
                        comparison_price = after_data.iloc[0]['High'].item()
                        actual_movement = "UP" if comparison_price > close_price else "DOWN"
                    else:  # prediction == "DOWN"
                        comparison_price = after_data.iloc[0]['Low'].item()
                        actual_movement = "DOWN" if comparison_price < close_price else "UP"

                    # Compare with prediction
                    result = "HIT" if prediction == actual_movement else "MISS"

                    # Update counters
                    total_checks += 1
                    if result == "HIT":
                        total_hits += 1

                    # Add to validation results
                    new_row = {
                        'company': company_name,
                        'ticker': ticker,
                        'prediction': prediction,
                        'before_close': close_price,
                        'comparison_price': comparison_price,
                        'actual_movement': actual_movement,
                        'result': result
                    }
                    validation_results = pd.concat([validation_results, pd.DataFrame([new_row])], ignore_index=True)
                else:
                    print(f"{company_name} ({ticker}): Insufficient stock data available")

            except Exception as e:
                print(f"{company_name} ({ticker}): Error retrieving stock data - {str(e)}")
        else:
            print(f"{company_name}: No ticker symbol mapping available")

    # Calculate and print hit rate
    if total_checks > 0:
        hit_rate = (total_hits / total_checks) * 100
        validation_results.attrs['hit_rate'] = hit_rate
    else:
        print("\nNo valid stock data was available for comparison")

# Save the validation results
print(validation_results)
print(f"Total predictions checked: {total_checks}")
print(f"Total hits: {total_hits}")
if total_checks > 0:
    hit_rate = (total_hits / total_checks) * 100
    print(f"Hit rate: {hit_rate:.2f}%")
# Out:
# ======================================================================
# PREDICTION VALIDATION AGAINST ACTUAL STOCK MOVEMENT
# ======================================================================
# YF.download() has changed argument auto_adjust default to True
#    company ticker prediction  before_close  comparison_price actual_movement  \
# 0  Walmart    WMT         UP     85.980003         87.650002              UP
# 1  Netflix   NFLX         UP    960.289978        977.000000              UP
#
#   result
# 0    HIT
# 1    HIT
# Total predictions checked: 2
# Total hits: 2
# Hit rate: 100.00%
# <ipython-input-8-8c0d37e97b30>:68: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   validation_results = pd.concat([validation_results, pd.DataFrame([new_row])], ignore_index=True)
